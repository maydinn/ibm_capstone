# %%
import pandas as pd
import numpy as np
import requests
import matplotlib

# %%
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library
from geopy.geocoders import Nominatim

# %%
from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs
import json
# Out:
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from pandas.io.json import json_normalize

# %%
CLIENT_ID = 'FKOQNU22VKJQJLNI4ZCLQ54X2GHRDASN4E4R3E2OGTVYUZBR' # your Foursquare ID
CLIENT_SECRET = 'I50ST3VC0UFIDVLOAMN1JJ55523T5IJ4XZPWCHE2SMWWIOYE' # your Foursquare Secret
ACCESS_TOKEN = '' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FKOQNU22VKJQJLNI4ZCLQ54X2GHRDASN4E4R3E2OGTVYUZBR
# CLIENT_SECRET:I50ST3VC0UFIDVLOAMN1JJ55523T5IJ4XZPWCHE2SMWWIOYE

# %%
radius = 1000

# %%
LIMIT=200

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="tr_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=FKOQNU22VKJQJLNI4ZCLQ54X2GHRDASN4E4R3E2OGTVYUZBR&client_secret=I50ST3VC0UFIDVLOAMN1JJ55523T5IJ4XZPWCHE2SMWWIOYE&ll=43.6534817,-79.3839347&v=20180604&radius=1000&limit=200'

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 100 around Ecco restaurant.'

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
items = results['response']['groups'][0]['items']
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                           name        categories        lat  \
# 0                             Downtown Toronto      Neighborhood  43.653232
# 1                       Nathan Phillips Square             Plaza  43.652270
# 2                                      Japango  Sushi Restaurant  43.655268
# 3                                       Indigo         Bookstore  43.653515
# 4                                         LUSH    Cosmetics Shop  43.653557
# 5                      CF Toronto Eaton Centre     Shopping Mall  43.654447
# 6                                  UNIQLO ユニクロ    Clothing Store  43.655910
# 7                                 Chatime 日出茶太   Bubble Tea Shop  43.655542
# 8  Four Seasons Centre for the Performing Arts      Concert Hall  43.650592
# 9                                    Poke Guys        Poke Place  43.654895
#
#          lng                                     labeledLatLngs  distance  cc  \
# 0 -79.385296  [{'label': 'display', 'lat': 43.65323167517444...       113  CA
# 1 -79.383516  [{'label': 'display', 'lat': 43.65227047322295...       138  CA
# 2 -79.385165  [{'label': 'display', 'lat': 43.65526771691681...       222  CA
# 3 -79.380696  [{'label': 'display', 'lat': 43.65351471121164...       260  CA
# 4 -79.380400  [{'label': 'display', 'lat': 43.653557, 'lng':...       284  CA
# 5 -79.380952                                                NaN       263  CA
# 6 -79.380641  [{'label': 'display', 'lat': 43.65591027779457...       378  CA
# 7 -79.384684  [{'label': 'display', 'lat': 43.65554164147378...       237  CA
# 8 -79.385806  [{'label': 'display', 'lat': 43.650592, 'lng':...       355  CA
# 9 -79.385052  [{'label': 'display', 'lat': 43.65489527525682...       181  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada                               [Toronto ON, Canada]
# 1  Toronto    ON  Canada  [100 Queen St W (at Bay St), Toronto ON M5H 2N...
# 2  Toronto    ON  Canada  [122 Elizabeth St. (at Dundas St. W), Toronto ...
# 3  Toronto    ON  Canada         [220 Yonge St, Toronto ON M5B 2H1, Canada]
# 4  Toronto    ON  Canada  [220 Yonge St, Unit B215-A (in Toronto Eaton C...
# 5  Toronto    ON  Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 6  Toronto    ON  Canada  [220 Yonge St (at Dundas St W), Toronto ON M5B...
# 7  Toronto    ON  Canada  [132 Dundas St W (btwn Bay & University), Toro...
# 8  Toronto    ON  Canada  [145 Queen St. W (at University Ave.), Toronto...
# 9  Toronto    ON  Canada  [112 Elizabeth St (at Dundas St W), Toronto ON...
#
#                      address              crossStreet postalCode  \
# 0                        NaN                      NaN        NaN
# 1             100 Queen St W                at Bay St    M5H 2N1
# 2          122 Elizabeth St.          at Dundas St. W    M5G 1P5
# 3               220 Yonge St                      NaN    M5B 2H1
# 4  220 Yonge St, Unit B215-A  in Toronto Eaton Centre    M5B 2H1
# 5               220 Yonge St      btwn Queen & Dundas    M5B 2H1
# 6               220 Yonge St           at Dundas St W    M5B 2H1
# 7            132 Dundas St W    btwn Bay & University    M5G 1C3
# 8            145 Queen St. W       at University Ave.    M5H 4G1
# 9           112 Elizabeth St           at Dundas St W    M5G 1P5
#
#                     neighborhood                        id
# 0                            NaN  5227bb01498e17bf485e6202
# 1                            NaN  4ad4c05ef964a520a6f620e3
# 2                            NaN  4ae7b27df964a52068ad21e3
# 3                 Downtown Yonge  4b2a6eb8f964a52012a924e3
# 4                            NaN  4bd0b30d41b9ef3b8fa0fae5
# 5  Downtown Toronto, Toronto, ON  4ad77a12f964a520260b21e3
# 6               Downtown Toronto  57eda381498ebe0e6ef40972
# 7                            NaN  4e2284b11fc7c0ef9857d143
# 8                            NaN  4ad4c062f964a520e5f720e3
# 9                            NaN  57bcd3b7498e652a678d0378

# %%
toronto= dataframe_filtered

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto['lat'], toronto['lng'], toronto['name'], toronto['categories']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto.plot(kind='scatter', x='lat',y='lng')
# Out:
# <AxesSubplot:xlabel='lat', ylabel='lng'>

# %%
from yellowbrick.cluster import KElbowVisualizer
X= toronto[['lat','lng']]
kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k = (1,10))
visu.fit(X)
visu.poof()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
k=3
kmeans = KMeans(n_clusters = k).fit(X)

# %%
toronto["cluster_id"] = kmeans.labels_

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
# set color scheme for the clusters
x = np.arange(4)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood, cluster in zip(toronto['lat'], toronto['lng'], toronto['name'], toronto['categories'], toronto['cluster_id']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plt.scatter(X['lat'], X['lng'], c = kmeans.labels_, s = 50, cmap = "viridis")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='black',alpha=0.5, label = 'Centroids')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-16e4484666bf> in <module>
# ----> 1 plt.scatter(X['lat'], X['lng'], c = kmeans.labels_, s = 50, cmap = "viridis")
#       2 plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='black',alpha=0.5, label = 'Centroids')
#
# NameError: name 'plt' is not defined

# %%
address = 'New York'

geolocator = Nominatim(user_agent="nr_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York are {}, {}.'.format(latitude, longitude))

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
results = requests.get(url).json()
print('There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items'])))
items = results['response']['groups'][0]['items']
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)

# %%
new_york = dataframe_filtered

# %%
map_new = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(new_york['lat'], new_york['lng'], new_york['name'], new_york['categories']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_new)  
    
map_new

# %%
new_york.plot(kind='scatter', x='lat',y='lng')

# %%
from yellowbrick.cluster import KElbowVisualizer
X= new_york[['lat','lng']]
kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k = (1,10))
visu.fit(X)
visu.poof()

# %%
k=4
kmeans = KMeans(n_clusters = k).fit(X)
new_york["cluster_id"] = kmeans.labels_

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
# set color scheme for the clusters
x = np.arange(4)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

map_new = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood, cluster in zip(new_york['lat'], new_york['lng'], new_york['name'], new_york['categories'], new_york['cluster_id']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(map_new)  
    
map_new

# %%
plt.scatter(X['lat'], X['lng'], c = kmeans.labels_, s = 50, cmap = "viridis")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='black',alpha=0.5, label = 'Centroids')

# %%
address = 'Paris'

geolocator = Nominatim(user_agent="pr_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Paris are {}, {}.'.format(latitude, longitude))

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
results = requests.get(url).json()
print('There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items'])))
items = results['response']['groups'][0]['items']
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)

# %%
paris = dataframe_filtered

# %%
map_paris = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(paris['lat'], paris['lng'], paris['name'], paris['categories']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_paris)  
    
map_paris

# %%
paris.plot(kind='scatter', x='lat',y='lng')

# %%
from yellowbrick.cluster import KElbowVisualizer
X= paris[['lat','lng']]
kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k = (1,10))
visu.fit(X)
visu.poof()

# %%
k=3
kmeans = KMeans(n_clusters = k).fit(X)
paris["cluster_id"] = kmeans.labels_

# %%
# set color scheme for the clusters
x = np.arange(4)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

map_paris = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood, cluster in zip(paris['lat'], paris['lng'], paris['name'], paris['categories'], paris['cluster_id']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(map_paris)  
    
map_paris

# %%
plt.scatter(X['lat'], X['lng'], c = kmeans.labels_, s = 50, cmap = "viridis")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='black',alpha=0.5, label = 'Centroids')

# %%
address = 'Berlin'

geolocator = Nominatim(user_agent="br_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Berlin are {}, {}.'.format(latitude, longitude))

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
results = requests.get(url).json()
print('There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items'])))
items = results['response']['groups'][0]['items']
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)

# %%
berlin = dataframe_filtered

# %%
map_berlin = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(berlin['lat'], berlin['lng'], berlin['name'], berlin['categories']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_berlin)  
    
map_berlin

# %%
berlin.plot(kind='scatter', x='lat',y='lng')

# %%
from yellowbrick.cluster import KElbowVisualizer
X= berlin[['lat','lng']]
kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k = (1,10))
visu.fit(X)
visu.poof()

# %%
k=4
kmeans = KMeans(n_clusters = k).fit(X)
berlin["cluster_id"] = kmeans.labels_

# %%
x = np.arange(4)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

map_berlin = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood, cluster in zip(berlin['lat'], berlin['lng'], berlin['name'], berlin['categories'], berlin['cluster_id']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(map_berlin)  
    
map_berlin

# %%
address = 'Istanbul'

geolocator = Nominatim(user_agent="is_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Istanbul are {}, {}.'.format(latitude, longitude))

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
results = requests.get(url).json()
print('There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items'])))
items = results['response']['groups'][0]['items']
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)

# %%
ist = dataframe_filtered

# %%
map_ist = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(ist['lat'], ist['lng'], ist['name'], ist['categories']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ist)  
    
map_ist

# %%
ist.plot(kind='scatter', x='lat',y='lng')

# %%
from yellowbrick.cluster import KElbowVisualizer
X= ist[['lat','lng']]
kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k = (1,10))
visu.fit(X)
visu.poof()

# %%
k=4
kmeans = KMeans(n_clusters = k).fit(X)
ist["cluster_id"] = kmeans.labels_

# %%
x = np.arange(4)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

map_ist = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood, cluster in zip(ist['lat'],ist['lng'], ist['name'], ist['categories'], ist['cluster_id']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(map_ist)  
    
map_ist
